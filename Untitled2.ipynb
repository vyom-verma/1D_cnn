# %% [markdown]
# <a href="https://colab.research.google.com/github/vyom-verma/1D_cnn/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
rating=pd.read_excel('/content/online_ratings.xls')
video=pd.read_excel('/content/video_list.xls')

# %%
video.isnull().count()
# Out:
# Online_id          120
# Experiment_id      120
# Lastfm_tag         120
# Artist             120
# Title              120
# Youtube_link       120
# Highlight_start    120
# Num_ratings        120
# VAQ_Estimate       120
# VAQ_Online         120
# AVG_Valence        120
# STD_Valence        120
# Q1_Valence         120
# Q2_Valence         120
# Q3_Valence         120
# AVG_Arousal        120
# STD_Arousal        120
# Q1_Arousal         120
# Q2_Arousal         120
# Q3_Arousal         120
# AVG_Dominance      120
# STD_Dominance      120
# Q1_Dominance       120
# Q2_Dominance       120
# Q3_Dominance       120
# dtype: int64

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1778 entries, 0 to 1777
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Online_id       1778 non-null   int64
#  1   Valence         1778 non-null   int64
#  2   Arousal         1778 non-null   int64
#  3   Dominance       1778 non-null   int64
#  4   Wheel_slice     1778 non-null   int64
#  5   Wheel_strength  1778 non-null   int64
# dtypes: int64(6)
# memory usage: 83.5 KB

# %%
import seaborn as sns
sns.distplot(rating['Valence'], hist=False)
sns.distplot(rating['Arousal'],hist=False)
# Out:
# <ipython-input-220-32e22ce81568>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rating['Valence'], hist=False)
# <ipython-input-220-32e22ce81568>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rating['Arousal'],hist=False)
# <Axes: xlabel='Arousal', ylabel='Density'>

# %%
rating_grouped=rating.groupby('Online_id').mean().reset_index()
rating_grouped.shape
# Out:
# (120, 6)

# %%
dataset=video.merge(rating_grouped,on='Online_id')
df=dataset.drop(columns=['Artist','Experiment_id','Title','Youtube_link','Lastfm_tag','Highlight_start','Num_ratings','Online_id','Wheel_slice','Wheel_strength'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   VAQ_Estimate   120 non-null    int64
#  1   VAQ_Online     120 non-null    int64
#  2   AVG_Valence    120 non-null    float64
#  3   STD_Valence    120 non-null    float64
#  4   Q1_Valence     120 non-null    float64
#  5   Q2_Valence     120 non-null    float64
#  6   Q3_Valence     120 non-null    float64
#  7   AVG_Arousal    120 non-null    float64
#  8   STD_Arousal    120 non-null    float64
#  9   Q1_Arousal     120 non-null    float64
#  10  Q2_Arousal     120 non-null    float64
#  11  Q3_Arousal     120 non-null    float64
#  12  AVG_Dominance  120 non-null    float64
#  13  STD_Dominance  120 non-null    float64
#  14  Q1_Dominance   120 non-null    float64
#  15  Q2_Dominance   120 non-null    float64
#  16  Q3_Dominance   120 non-null    float64
#  17  Valence        120 non-null    float64
#  18  Arousal        120 non-null    float64
#  19  Dominance      120 non-null    float64
# dtypes: float64(18), int64(2)
# memory usage: 19.7 KB

# %%
X=df.drop(columns=['AVG_Dominance','STD_Dominance','Q1_Dominance','Q2_Dominance','Q3_Dominance','Valence','Arousal','Dominance'])
Y=df[['Valence','Arousal']]
X.shape
# Out:
# (120, 12)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
X_train_Scaled=StandardScaler().fit_transform(X_train)
X_test_Scaled=StandardScaler().fit_transform(X_test)
X_train=np.array(X_train)
X_test=np.array(X_test)
X_train.shape
# Out:
# (96, 12)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import Softmax,BatchNormalization

# %%
model=Sequential()
model.add(Conv1D(filters=3, activation='relu',padding='same',kernel_size=3, strides=2, input_shape=(12,1)))
model.add(MaxPooling1D(pool_size=2, strides = 2))
model.add(BatchNormalization())
model.add(Conv1D(filters=3, activation='relu',padding='same',kernel_size=3))
model.add(MaxPooling1D(pool_size=2, strides = 2))

model.add(Flatten())
model.add(Dense(10, activation='relu',input_dim=17))
model.add(Dropout(0.2))
model.add(Dense(5, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2,activation='Softmax'))
model.compile(optimizer='Adam', loss='mse',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_68 (Conv1D)          (None, 6, 3)              12
#
#  max_pooling1d_48 (MaxPoolin  (None, 3, 3)             0
#  g1D)
#
#  batch_normalization_25 (Bat  (None, 3, 3)             12
#  chNormalization)
#
#  conv1d_69 (Conv1D)          (None, 3, 3)              30
#
#  max_pooling1d_49 (MaxPoolin  (None, 1, 3)             0
#  g1D)
#
#  flatten_31 (Flatten)        (None, 3)                 0
#
#  dense_106 (Dense)           (None, 10)                40
#
#  dropout_65 (Dropout)        (None, 10)                0
#
#  dense_107 (Dense)           (None, 5)                 55
#
#  dropout_66 (Dropout)        (None, 5)                 0
#
#  dense_108 (Dense)           (None, 2)                 12
#
# =================================================================
# Total params: 161
# Trainable params: 155
# Non-trainable params: 6
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train, epochs = 100,batch_size=32,validation_data=(X_test,y_test),verbose=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 139ms/step - loss: 21.9523 - accuracy: 0.7604 - val_loss: 22.1239 - val_accuracy: 0.4583
# Epoch 2/100
# 3/3 [==============================] - 0s 29ms/step - loss: 21.9479 - accuracy: 0.7604 - val_loss: 22.1269 - val_accuracy: 0.4583
# Epoch 3/100
# 3/3 [==============================] - 0s 28ms/step - loss: 21.9555 - accuracy: 0.7604 - val_loss: 22.1300 - val_accuracy: 0.4583
# Epoch 4/100
# 3/3 [==============================] - 0s 28ms/step - loss: 21.9470 - accuracy: 0.7604 - val_loss: 22.1328 - val_accuracy: 0.4583
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 21.9401 - accuracy: 0.7604 - val_loss: 22.1359 - val_accuracy: 0.4583
# Epoch 6/100
# 3/3 [==============================] - 0s 53ms/step - loss: 21.9199 - accuracy: 0.7500 - val_loss: 22.1395 - val_accuracy: 0.4583
# Epoch 7/100
# 3/3 [==============================] - 0s 86ms/step - loss: 21.9096 - accuracy: 0.7604 - val_loss: 22.1432 - val_accuracy: 0.4583
# Epoch 8/100
# 3/3 [==============================] - 0s 87ms/step - loss: 21.9213 - accuracy: 0.7604 - val_loss: 22.1465 - val_accuracy: 0.4583
# Epoch 9/100
# 3/3 [==============================] - 0s 87ms/step - loss: 21.8939 - accuracy: 0.7604 - val_loss: 22.1499 - val_accuracy: 0.4583
# Epoch 86/100
# 3/3 [==============================] - 0s 20ms/step - loss: 21.7284 - accuracy: 0.7604 - val_loss: 22.0238 - val_accuracy: 0.4583
# Epoch 87/100
# 3/3 [==============================] - 0s 23ms/step - loss: 21.7228 - accuracy: 0.7604 - val_loss: 22.0231 - val_accuracy: 0.4583
# Epoch 88/100
# 3/3 [==============================] - 0s 29ms/step - loss: 21.7233 - accuracy: 0.7604 - val_loss: 22.0224 - val_accuracy: 0.4583
# Epoch 89/100
# 3/3 [==============================] - 0s 21ms/step - loss: 21.7321 - accuracy: 0.7604 - val_loss: 22.0216 - val_accuracy: 0.4583
# Epoch 90/100
# 3/3 [==============================] - 0s 28ms/step - loss: 21.7228 - accuracy: 0.7604 - val_loss: 22.0208 - val_accuracy: 0.4583
# Epoch 91/100
# 3/3 [==============================] - 0s 21ms/step - loss: 21.7166 - accuracy: 0.7604 - val_loss: 22.0195 - val_accuracy: 0.4583
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 21.7359 - accuracy: 0.7604 - val_loss: 22.0185 - val_accuracy: 0.4583
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 21.7261 - accuracy: 0.7604 - val_loss: 22.0173 - val_accuracy: 0.4583
# Epoch 94/100
# 3/3 [==============================] - 0s 23ms/step - loss: 21.7252 - accuracy: 0.7604 - val_loss: 22.0160 - val_accuracy: 0.4583
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 21.7154 - accuracy: 0.7604 - val_loss: 22.0146 - val_accuracy: 0.4583
# Epoch 96/100
# 3/3 [==============================] - 0s 29ms/step - loss: 21.7497 - accuracy: 0.7604 - val_loss: 22.0134 - val_accuracy: 0.4583
# Epoch 97/100
# 3/3 [==============================] - 0s 20ms/step - loss: 21.7166 - accuracy: 0.7604 - val_loss: 22.0122 - val_accuracy: 0.4583
# Epoch 98/100
# 3/3 [==============================] - 0s 29ms/step - loss: 21.7287 - accuracy: 0.7604 - val_loss: 22.0114 - val_accuracy: 0.4583
# Epoch 99/100
# 3/3 [==============================] - 0s 20ms/step - loss: 21.7284 - accuracy: 0.7604 - val_loss: 22.0104 - val_accuracy: 0.4583
# Epoch 100/100
# 3/3 [==============================] - 0s 21ms/step - loss: 21.7188 - accuracy: 0.7604 - val_loss: 22.0095 - val_accuracy: 0.4583

# %%
import matplotlib.pyplot as plt
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(loss)+1)

plt.plot(epochs,loss,'y', label='training loss')
plt.plot(epochs,val_loss,'r' , label='validation loss')
plt.legend()
plt.title('Training and Validation loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
import matplotlib.pyplot as plt
a=history.history['accuracy']
val_a=history.history['val_accuracy']
epochs=range(1,len(loss)+1)

plt.plot(epochs,a,'y' , label='training accuracy')
plt.plot(epochs,val_a,'r' , label='validation accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
